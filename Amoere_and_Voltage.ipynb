# %% [markdown]
# # 옴의 법칙

# %% [markdown]
# ![vm_sc3012_04_i01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 위 공식을 활용해서 저항과 전압을 입력받은 후 전류의 세기를 예측하는 모델을
# 구현해 보도록 하겠습니다.

# %%
import matplotlib as plt
from sklearn.linear_model import LinearRegression

# %%
class Ampere:
    def __init__(self):
        pass
    def inputdata(self, resistance):
        amperelist = []
        for voltage in range(6):
            ampere = voltage / resistance
            amperelist.append(ampere)
        return amperelist
